# %%
import pandas as pd
import numpy as np

# %%
food_df = pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv")

# %%
food_df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
food_df.shape
# Out:
# (60943, 12)

# %%
food_df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %% [markdown]
# ### Question 11:
# #### What is the total sum of Aminal Fat produced in 2014 and 2017 respectively

# %%
#Question 11: What is the total sum of Aminal Fat produced in 2014 and 2017 respectively

food_df.groupby(['Item'],as_index=False)[['Y2014','Y2017']].sum()
#ans = 209460.54 and 269617.53
# Out:
#                     Item      Y2014      Y2017
# 0      Alcohol, Non-Food    2403.00    2348.00
# 1    Alcoholic Beverages  102410.11   95581.06
# 2        Animal Products   11935.65   11547.65
# 3            Animal fats  209460.54  269617.53
# 4    Apples and products    9499.23   10198.90
# ..                   ...        ...        ...
# 114    Vegetables, Other  155038.96  157752.59
# 115     Vegetal Products  107145.19  107655.20
# 116   Wheat and products  232670.13  240047.62
# 117                 Wine    4497.36    4178.02
# 118                 Yams  200396.96  229174.59
#
# [119 rows x 3 columns]

# %%
#attempt to select only Animal fats
total_sum_AF = food_df.groupby(['Animal fats'] in ['Item'])[['Y2014','Y2017']].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-64697e03aa28> in <module>
#       1 #attempt to select only Animal fats
# ----> 2 total_sum_AF = food_df.groupby(['Animal fats'] in ['Item'])[['Y2014','Y2017']].sum()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6715         axis = self._get_axis_number(axis)
#    6716
# -> 6717         return DataFrameGroupBy(
#    6718             obj=self,
#    6719             keys=by,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     558             from pandas.core.groupby.grouper import get_grouper
#     559
# ...

# %%
#Question 12
food_df.mean()
#ans = 135.236 and 1603.404
# Out:
# Area Code        134.265576
# Item Code       2687.176706
# Element Code    3814.856456
# Y2014            134.196282
# Y2015            135.235966
# Y2016            136.555222
# Y2017            140.917765
# Y2018            143.758381
# dtype: float64

# %%
food_df.std()
# Out:
# Area Code         72.605709
# Item Code        146.055739
# Element Code    2212.007033
# Y2014           1567.663696
# Y2015           1603.403984
# Y2016           1640.007194
# Y2017           1671.862359
# Y2018           1710.782658
# dtype: float64

# %%
display(food_df.mean(), food_df.std())
# Out:
# Area Code        134.265576
# Item Code       2687.176706
# Element Code    3814.856456
# Y2014            134.196282
# Y2015            135.235966
# Y2016            136.555222
# Y2017            140.917765
# Y2018            143.758381
# dtype: float64
# Area Code         72.605709
# Item Code        146.055739
# Element Code    2212.007033
# Y2014           1567.663696
# Y2015           1603.403984
# Y2016           1640.007194
# Y2017           1671.862359
# Y2018           1710.782658
# dtype: float64

# %%
#Question 13
food_df.isnull().sum()
# ans = 1535 and 2.52
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
# Question 13 - Calculate percentage of missing data
1535/60943 * 100
# Out:
# 2.5187470259094566

# %%
food_df.corr().sum()
# Out:
# Area Code       1.022186
# Item Code       1.075654
# Element Code    1.095431
# Y2014           5.033173
# Y2015           5.016861
# Y2016           5.026162
# Y2017           5.024920
# Y2018           5.025198
# dtype: float64

# %%
#Attempt to get the correlation another way with specifics to element code
food_df.groupby(['Element Code'])[['Y2014','Y2015','Y2016','Y2017']].corr().sum()
# Out:
# Y2014    67.957719
# Y2015    67.454574
# Y2016    68.288095
# Y2017    67.635081
# dtype: float64

# %%
# Question 15: What year has the highest sum of import quality?
food_df.groupby(['Element'],as_index=False)[['Y2014','Y2015','Y2016','Y2017']].sum()
#ans = 2017
# Out:
#                                    Element       Y2014       Y2015  \
# 0                 Domestic supply quantity  1996716.35  2021493.55
# 1                          Export Quantity   150020.64   157614.47
# 2       Fat supply quantity (g/capita/day)    10225.56    10235.74
# 3                                     Feed   216927.89   225050.22
# 4                                     Food  1212332.49  1232361.10
# 5            Food supply (kcal/capita/day)   454257.00   453383.00
# 6      Food supply quantity (kg/capita/yr)    49650.63    49345.13
# 7                          Import Quantity   274144.48   267018.46
# 8                                   Losses   153223.00   155439.00
# 9                    Other uses (non-food)    78718.13    66254.41
# 10                              Processing   282923.00   287929.00
# 11                              Production  1931287.75  1947019.39
# 12  Protein supply quantity (g/capita/day)    11836.46    11833.95
# ...

# %%
# I wish i could write a code that will only examine import quantity and not all the values, to save resources

# %%
# question 16: What is the total number of the sum of production in 2014?
food_df.groupby(['Element'])['Y2014'].sum()
#ans = 1931287.75
# Out:
# Element
# Domestic supply quantity                  1996716.35
# Export Quantity                            150020.64
# Fat supply quantity (g/capita/day)          10225.56
# Feed                                       216927.89
# Food                                      1212332.49
# Food supply (kcal/capita/day)              454257.00
# Food supply quantity (kg/capita/yr)         49650.63
# Import Quantity                            274144.48
# Losses                                     153223.00
# Other uses (non-food)                       78718.13
# Processing                                 282923.00
# Production                                1931287.75
# Protein supply quantity (g/capita/day)      11836.46
# Residuals                                   30149.00
# Seed                                        21922.92
# Stock Variation                             58749.83
# Total Population - Both sexes             1031585.00
# Tourist consumption                           416.00
# ...

# %%
# question 17: Which of these elements had the highest sum in 2018? 

food_df.groupby(['Element'],as_index=False)['Y2018'].sum()

#ans = Domestic supply quantity
# Out:
#                                    Element       Y2018
# 0                 Domestic supply quantity  2161192.10
# 1                          Export Quantity   181594.80
# 2       Fat supply quantity (g/capita/day)    10258.69
# 3                                     Feed   233489.68
# 4                                     Food  1303841.28
# 5            Food supply (kcal/capita/day)   455261.00
# 6      Food supply quantity (kg/capita/yr)    49056.85
# 7                          Import Quantity   287997.09
# 8                                   Losses   163902.00
# 9                    Other uses (non-food)    91300.97
# 10                              Processing   308429.00
# 11                              Production  2075072.89
# 12  Protein supply quantity (g/capita/day)    11833.56
# 13                               Residuals    34864.00
# 14                                    Seed    25263.14
# 15                         Stock Variation    20577.91
# ...

# %%
# Question 18: Which of these elements had the 3rd lowest sum in 2018
Q_18 = food_df.groupby(['Element'],as_index=False)['Y2018'].sum()
print(Q_18)

#ans = Protein supply quantity
# Out:
#                                    Element       Y2018
# 0                 Domestic supply quantity  2161192.10
# 1                          Export Quantity   181594.80
# 2       Fat supply quantity (g/capita/day)    10258.69
# 3                                     Feed   233489.68
# 4                                     Food  1303841.28
# 5            Food supply (kcal/capita/day)   455261.00
# 6      Food supply quantity (kg/capita/yr)    49056.85
# 7                          Import Quantity   287997.09
# 8                                   Losses   163902.00
# 9                    Other uses (non-food)    91300.97
# 10                              Processing   308429.00
# 11                              Production  2075072.89
# 12  Protein supply quantity (g/capita/day)    11833.56
# 13                               Residuals    34864.00
# 14                                    Seed    25263.14
# 15                         Stock Variation    20577.91
# ...

# %%
Q_18.sort_values(by=['Y2018'])
# Out:
#                                    Element       Y2018
# 17                     Tourist consumption       90.00
# 2       Fat supply quantity (g/capita/day)    10258.69
# 12  Protein supply quantity (g/capita/day)    11833.56
# 15                         Stock Variation    20577.91
# 14                                    Seed    25263.14
# 13                               Residuals    34864.00
# 6      Food supply quantity (kg/capita/yr)    49056.85
# 9                    Other uses (non-food)    91300.97
# 8                                   Losses   163902.00
# 1                          Export Quantity   181594.80
# 3                                     Feed   233489.68
# 7                          Import Quantity   287997.09
# 10                              Processing   308429.00
# 5            Food supply (kcal/capita/day)   455261.00
# 16           Total Population - Both sexes  1140605.00
# 4                                     Food  1303841.28
# ...

# %%
# Question 19: What is the total import quantity in Algeria in 2018?
Alg = food_df.groupby(['Area','Element'],as_index=False)['Y2018'].sum()
Alg[(Alg['Area'] == 'Algeria') & (Alg['Element'] == 'Import Quantity')]

#ans = 36238.29
# Out:
#       Area          Element     Y2018
# 7  Algeria  Import Quantity  36238.29

# %%
# Question 20: What is the total number of countries in the dataset?
count_countries = food_df["Area"].unique()
print(count_countries)
# Out:
# ['Algeria' 'Angola' 'Benin' 'Botswana' 'Burkina Faso' 'Cabo Verde'
#  'Cameroon' 'Central African Republic' 'Chad' 'Comoros' 'Congo'
#  "C�te d'Ivoire" 'Djibouti' 'Egypt' 'Eswatini' 'Ethiopia' 'Ethiopia PDR'
#  'Gabon' 'Gambia' 'Ghana' 'Guinea' 'Guinea-Bissau' 'Kenya' 'Lesotho'
#  'Liberia' 'Madagascar' 'Malawi' 'Mali' 'Mauritania' 'Mauritius' 'Morocco'
#  'Mozambique' 'Namibia' 'Niger' 'Nigeria' 'Rwanda' 'Sao Tome and Principe'
#  'Senegal' 'Seychelles' 'Sierra Leone' 'South Africa' 'Sudan'
#  'Sudan (former)' 'Togo' 'Tunisia' 'Uganda' 'United Republic of Tanzania'
#  'Zambia' 'Zimbabwe']

# %%
len(count_countries)
# Out:
# 49
